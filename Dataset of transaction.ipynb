# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conda update numexpr

# %%
df = pd.read_csv("Purchase_Pattern_Analysis.csv")

# %%
print(df.head())
# Out:
#    Customer ID      Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858      Sean  Rodriguez      F  10/20/2002               35.47
# 1        26381  Michelle     Phelps    NaN  10/24/1985             2552.72
# 2       305449     Jacob   Williams      M  10/25/1981              115.97
# 3       988259    Nathan     Snyder      M  10/26/1977               11.31
# 4       764762   Crystal      Knapp      F  11/02/1951               62.21
#
#          Date               Merchant Name Product Category  Quantity  \
# 0  04/03/2023               Smith-Russell         Cosmetic       3.0
# 1  07/17/2023      Peck, Spence and Young           Travel       2.0
# 2  09/20/2023                  Steele Inc         Clothing       1.0
# 3  01/11/2023  Wilson, Wilson and Russell         Cosmetic       1.0
# 4  06/13/2023               Palmer-Hinton      Electronics       2.0
#
#    Price per Unit  Total Sales
# 0            50.0          150
# 1           500.0         1000
# 2            30.0           30
# 3           500.0          500
# 4            50.0          100

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         50000 non-null  int64
#  1   Name                50000 non-null  str
#  2   Surname             50000 non-null  str
#  3   Gender              44953 non-null  str
#  4   Birthdate           50000 non-null  str
#  5   Transaction Amount  50000 non-null  float64
#  6   Date                50000 non-null  str
#  7   Merchant Name       50000 non-null  str
#  8   Product Category    50000 non-null  str
#  9   Quantity            1000 non-null   float64
#  10  Price per Unit      1000 non-null   float64
#  11  Total Sales         50000 non-null  int64
# dtypes: float64(3), int64(2), str(7)
# memory usage: 7.3 MB
# None

# %%
print(df.describe())
# Out:
#         Customer ID  Transaction Amount     Quantity  Price per Unit  \
# count   50000.00000        50000.000000  1000.000000     1000.000000
# mean   500136.79696          442.119239     2.514000      179.890000
# std    288232.43164          631.669724     1.132734      189.681356
# min        29.00000            5.010000     1.000000       25.000000
# 25%    251191.50000           79.007500     1.000000       30.000000
# 50%    499520.50000          182.195000     3.000000       50.000000
# 75%    749854.25000          470.515000     4.000000      300.000000
# max    999997.00000         2999.880000     4.000000      500.000000
#
#         Total Sales
# count  50000.000000
# mean       9.120000
# std      101.692809
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max     2000.000000

# %%
df.mean(numeric_only = True)
# Out:
# Customer ID           500136.796960
# Transaction Amount       442.119239
# Quantity                   2.514000
# Price per Unit           179.890000
# Total Sales                9.120000
# dtype: float64

# %%
df.median(numeric_only = True)
# Out:
# Customer ID           499520.500
# Transaction Amount       182.195
# Quantity                   3.000
# Price per Unit            50.000
# Total Sales                0.000
# dtype: float64

# %%
df.mode()
# Out:
#        Customer ID     Name Surname Gender   Birthdate  Transaction Amount  \
# 0               29  Michael   Smith      F  11/01/1954               68.89
# 1               51      NaN     NaN    NaN         NaN                 NaN
# 2               54      NaN     NaN    NaN         NaN                 NaN
# 3               83      NaN     NaN    NaN         NaN                 NaN
# 4               90      NaN     NaN    NaN         NaN                 NaN
# ...            ...      ...     ...    ...         ...                 ...
# 49995       999904      NaN     NaN    NaN         NaN                 NaN
# 49996       999914      NaN     NaN    NaN         NaN                 NaN
# 49997       999942      NaN     NaN    NaN         NaN                 NaN
# 49998       999949      NaN     NaN    NaN         NaN                 NaN
# 49999       999997      NaN     NaN    NaN         NaN                 NaN
#
#              Date Merchant Name Product Category  Quantity  Price per Unit  \
# 0      06/30/2023     Smith Ltd       Restaurant       4.0            50.0
# 1             NaN           NaN              NaN       NaN             NaN
# 2             NaN           NaN              NaN       NaN             NaN
# 3             NaN           NaN              NaN       NaN             NaN
# 4             NaN           NaN              NaN       NaN             NaN
# ...           ...           ...              ...       ...             ...
# 49995         NaN           NaN              NaN       NaN             NaN
# 49996         NaN           NaN              NaN       NaN             NaN
# 49997         NaN           NaN              NaN       NaN             NaN
# 49998         NaN           NaN              NaN       NaN             NaN
# 49999         NaN           NaN              NaN       NaN             NaN
#
#        Total Sales
# 0              0.0
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 49995          NaN
# 49996          NaN
# 49997          NaN
# 49998          NaN
# 49999          NaN
#
# [50000 rows x 12 columns]

# %%
print(df.isnull().sum())
# Out:
# Customer ID               0
# Name                      0
# Surname                   0
# Gender                 5047
# Birthdate                 0
# Transaction Amount        0
# Date                      0
# Merchant Name             0
# Product Category          0
# Quantity              49000
# Price per Unit        49000
# Total Sales               0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar = False)
plt.show()

# %%
df.dropna()
# Out:
#      Customer ID     Name    Surname Gender   Birthdate  Transaction Amount  \
# 0         752858     Sean  Rodriguez      F  10/20/2002               35.47
# 2         305449    Jacob   Williams      M  10/25/1981              115.97
# 3         988259   Nathan     Snyder      M  10/26/1977               11.31
# 4         764762  Crystal      Knapp      F  11/02/1951               62.21
# 5         576539   Monica   Bartlett      F  10/20/2001               99.14
# ..           ...      ...        ...    ...         ...                 ...
# 995       558372   Steven     Graham      M  11/02/1951               78.01
# 996       214860  Melissa  Henderson      M  10/30/1963              610.47
# 997       269210   Ashley     Becker      M  11/02/1948               70.11
# 998       401786     Chad      Smith      M  10/24/1986              153.13
# 999       170045     John      Brown      F  10/28/1968              283.46
#
#            Date                     Merchant Name Product Category  Quantity  \
# 0    04/03/2023                     Smith-Russell         Cosmetic       3.0
# 2    09/20/2023                        Steele Inc         Clothing       1.0
# 3    01/11/2023        Wilson, Wilson and Russell         Cosmetic       1.0
# 4    06/13/2023                     Palmer-Hinton      Electronics       2.0
# 5    08/24/2023            Tran, Torres and Joyce         Cosmetic       1.0
# ..          ...                               ...              ...       ...
# 995  06/11/2023                       Cline-Grant       Restaurant       1.0
# 996  04/27/2023                    Patton-Freeman      Electronics       3.0
# 997  05/20/2023                         Scott Inc       Restaurant       4.0
# 998  08/19/2023          Hayes, Schmidt and Novak         Clothing       3.0
# 999  01/27/2023  Velasquez, Mitchell and Thompson      Electronics       4.0
#
#      Price per Unit  Total Sales
# 0              50.0          150
# 2              30.0           30
# 3             500.0          500
# 4              50.0          100
# 5              30.0           30
# ..              ...          ...
# 995            50.0           50
# 996            30.0           90
# 997            25.0          100
# 998            50.0          150
# 999            30.0          120
#
# [892 rows x 12 columns]

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Customer ID           0
# Name                  0
# Surname               0
# Gender                0
# Birthdate             0
# Transaction Amount    0
# Date                  0
# Merchant Name         0
# Product Category      0
# Quantity              0
# Price per Unit        0
# Total Sales           0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Customer ID           0
# Name                  0
# Surname               0
# Gender                0
# Birthdate             0
# Transaction Amount    0
# Date                  0
# Merchant Name         0
# Product Category      0
# Quantity              0
# Price per Unit        0
# Total Sales           0
# dtype: int64

# %%
df.shape
# Out:
# (892, 12)

# %%
df.dropna(inplace = True)
df.shape
# Out:
# (892, 12)

# %%
df.head()
# Out:
#    Customer ID     Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858     Sean  Rodriguez      F  10/20/2002               35.47
# 2       305449    Jacob   Williams      M  10/25/1981              115.97
# 3       988259   Nathan     Snyder      M  10/26/1977               11.31
# 4       764762  Crystal      Knapp      F  11/02/1951               62.21
# 5       576539   Monica   Bartlett      F  10/20/2001               99.14
#
#          Date               Merchant Name Product Category  Quantity  \
# 0  04/03/2023               Smith-Russell         Cosmetic       3.0
# 2  09/20/2023                  Steele Inc         Clothing       1.0
# 3  01/11/2023  Wilson, Wilson and Russell         Cosmetic       1.0
# 4  06/13/2023               Palmer-Hinton      Electronics       2.0
# 5  08/24/2023      Tran, Torres and Joyce         Cosmetic       1.0
#
#    Price per Unit  Total Sales
# 0            50.0          150
# 2            30.0           30
# 3           500.0          500
# 4            50.0          100
# 5            30.0           30

# %%
transactions = df.groupby('Customer ID')['Product Category'].apply(list)
transactions.head()
# Out:
# Customer ID
# 1246         [Travel]
# 2569         [Market]
# 4800    [Electronics]
# 6526         [Market]
# 6659         [Travel]
# Name: Product Category, dtype: object

# %%
transactions = transactions.values.tolist()

# %%
transactions = df.groupby(['Customer ID', 'Date'])['Product Category'].apply(list)
transactions.head()
# Out:
# Customer ID  Date
# 1246         08/13/2023         [Travel]
# 2569         05/04/2023         [Market]
# 4800         06/30/2023    [Electronics]
# 6526         02/17/2023         [Market]
# 6659         06/25/2023         [Travel]
# Name: Product Category, dtype: object

# %%
transactions = transactions.values.tolist()

# %%
print(transactions[:5])
# Out:
# [['Travel'], ['Market'], ['Electronics'], ['Market'], ['Travel']]

# %%
df.fillna('MISSING')
# Out:
#      Customer ID     Name    Surname Gender   Birthdate  Transaction Amount  \
# 0         752858     Sean  Rodriguez      F  10/20/2002               35.47
# 2         305449    Jacob   Williams      M  10/25/1981              115.97
# 3         988259   Nathan     Snyder      M  10/26/1977               11.31
# 4         764762  Crystal      Knapp      F  11/02/1951               62.21
# 5         576539   Monica   Bartlett      F  10/20/2001               99.14
# ..           ...      ...        ...    ...         ...                 ...
# 995       558372   Steven     Graham      M  11/02/1951               78.01
# 996       214860  Melissa  Henderson      M  10/30/1963              610.47
# 997       269210   Ashley     Becker      M  11/02/1948               70.11
# 998       401786     Chad      Smith      M  10/24/1986              153.13
# 999       170045     John      Brown      F  10/28/1968              283.46
#
#            Date                     Merchant Name Product Category  Quantity  \
# 0    04/03/2023                     Smith-Russell         Cosmetic       3.0
# 2    09/20/2023                        Steele Inc         Clothing       1.0
# 3    01/11/2023        Wilson, Wilson and Russell         Cosmetic       1.0
# 4    06/13/2023                     Palmer-Hinton      Electronics       2.0
# 5    08/24/2023            Tran, Torres and Joyce         Cosmetic       1.0
# ..          ...                               ...              ...       ...
# 995  06/11/2023                       Cline-Grant       Restaurant       1.0
# 996  04/27/2023                    Patton-Freeman      Electronics       3.0
# 997  05/20/2023                         Scott Inc       Restaurant       4.0
# 998  08/19/2023          Hayes, Schmidt and Novak         Clothing       3.0
# 999  01/27/2023  Velasquez, Mitchell and Thompson      Electronics       4.0
#
#      Price per Unit  Total Sales
# 0              50.0          150
# 2              30.0           30
# 3             500.0          500
# 4              50.0          100
# 5              30.0           30
# ..              ...          ...
# 995            50.0           50
# 996            30.0           90
# 997            25.0          100
# 998            50.0          150
# 999            30.0          120
#
# [892 rows x 12 columns]

# %%
print(df.columns)
# Out:
# Index(['Customer ID', 'Name', 'Surname', 'Gender', 'Birthdate',
#        'Transaction Amount', 'Date', 'Merchant Name', 'Product Category',
#        'Quantity', 'Price per Unit', 'Total Sales'],
#       dtype='str')

# %%
sns.boxplot(x = df['Transaction Amount'])
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.groupby('Date')['Transaction Amount'].sum().plot()
plt.show()

# %%
df = pd.read_csv(("Purchase_Pattern_Analysis.csv"))

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Dataset of transaction.ipynb',
#  'Purchase_Pattern_Analysis.csv']

# %%
import pandas as pd 

df = pd.read_csv("Purchase_Pattern_Analysis.csv")

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Name                      0
# Surname                   0
# Gender                 5047
# Birthdate                 0
# Transaction Amount        0
# Date                      0
# Merchant Name             0
# Product Category          0
# Quantity              49000
# Price per Unit        49000
# Total Sales               0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Customer ID            0.000
# Name                   0.000
# Surname                0.000
# Gender                10.094
# Birthdate              0.000
# Transaction Amount     0.000
# Date                   0.000
# Merchant Name          0.000
# Product Category       0.000
# Quantity              98.000
# Price per Unit        98.000
# Total Sales            0.000
# dtype: float64

# %%
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(df['Transaction Amount']))
outliers = df[z > 3]

print(outliers)
# Out:
#        Customer ID         Name    Surname Gender   Birthdate  \
# 1            26381     Michelle     Phelps    NaN  10/24/1985
# 39           11697        Jason    Johnson      F  10/20/2001
# 61          805732      Sabrina      White      F  10/25/1980
# 67           34415         Juan      Kelly      F  10/22/1995
# 96          981118      Anthony     Arnold      M  10/28/1971
# ...            ...          ...        ...    ...         ...
# 49869       388076         Paul      Ortiz      F  10/29/1964
# 49881       120060        Sarah       Pham      F  10/29/1967
# 49922       892727       Angela  Macdonald      M  10/24/1984
# 49926       958102        Brian     Bailey      M  10/30/1962
# 49931       167795  Christopher    Coleman      M  10/25/1980
#
#        Transaction Amount        Date              Merchant Name  \
# 1                 2552.72  07/17/2023     Peck, Spence and Young
# 39                2423.86  09/02/2023                King-Wright
# 61                2612.99  07/03/2023     Woodard, Boyd and Mays
# 67                2770.66  07/28/2023               Peterson LLC
# 96                2362.42  06/28/2023  Thomas, Simpson and Tyler
# ...                   ...         ...                        ...
# 49869             2936.09  09/09/2023                 Jacobs LLC
# 49881             2660.12  04/03/2023            Kelly-Hernandez
# 49922             2498.22  04/01/2023  Shields, Freeman and Hale
# 49926             2826.36  07/04/2023                  Lopez PLC
# 49931             2948.35  10/12/2023                  Hall-Boyd
#
#       Product Category  Quantity  Price per Unit  Total Sales
# 1               Travel       2.0           500.0         1000
# 39              Travel       1.0            50.0           50
# 61              Travel       2.0            50.0          100
# 67              Travel       1.0           300.0          300
# 96              Travel       2.0           500.0         1000
# ...                ...       ...             ...          ...
# 49869           Travel       NaN             NaN            0
# 49881           Travel       NaN             NaN            0
# 49922           Travel       NaN             NaN            0
# 49926           Travel       NaN             NaN            0
# 49931           Travel       NaN             NaN            0
#
# [1845 rows x 12 columns]

# %%
Q1 = df['Transaction Amount'].quantile(0.25)
Q3 = df['Transaction Amount'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Transaction Amount'] < lower_bound) | (df['Transaction Amount'] > upper_bound)]

print(outliers)
# Out:
#        Customer ID      Name    Surname Gender   Birthdate  \
# 1            26381  Michelle     Phelps    NaN  10/24/1985
# 19          401993    Steven      Smith      M  10/21/1999
# 28          744599   William  Contreras      F  10/20/2003
# 33          485255       Amy     Mercer      F  10/28/1970
# 36          796123   Darlene     Tucker      M  11/01/1953
# ...            ...       ...        ...    ...         ...
# 49939       691543    Andrew   Griffith      F  10/27/1975
# 49956       751871   Jessica     Cooper      M  10/27/1972
# 49982       728409    Debbie    Griffin      M  10/22/1994
# 49983        91701    Joseph     Lawson      M  10/24/1985
# 49985       637225    Karina   Caldwell      F  10/31/1959
#
#        Transaction Amount        Date              Merchant Name  \
# 1                 2552.72  07/17/2023     Peck, Spence and Young
# 19                1468.14  05/14/2023  Thompson, Lopez and Mason
# 28                1479.49  04/15/2023    Fuller, Jones and White
# 33                2071.69  09/20/2023     Peck, Horn and Stanley
# 36                1745.40  03/05/2023                Manning Inc
# ...                   ...         ...                        ...
# 49939             1981.75  03/05/2023                Allen Group
# 49956             1261.90  08/18/2023    Woods, Medina and Tyler
# 49982             2000.82  08/05/2023             James and Sons
# 49983             1228.36  04/21/2023                  Davis Ltd
# 49985             2108.49  04/17/2023             Greer and Sons
#
#       Product Category  Quantity  Price per Unit  Total Sales
# 1               Travel       2.0           500.0         1000
# 19              Travel       3.0           300.0          900
# 28              Travel       1.0            30.0           30
# 33              Travel       3.0            50.0          150
# 36              Travel       3.0            25.0           75
# ...                ...       ...             ...          ...
# 49939           Travel       NaN             NaN            0
# 49956           Travel       NaN             NaN            0
# 49982           Travel       NaN             NaN            0
# 49983           Travel       NaN             NaN            0
# 49985           Travel       NaN             NaN            0
#
# [5617 rows x 12 columns]

# %%
Q1 = df['Transaction Amount'].quantile(0.25)
Q3 = df['Transaction Amount'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %%
[['Apple', 'Grapes', 'Mango'],
 ['Apple', 'Carrot'],
 ...]
# Out:
# [['Apple', 'Grapes', 'Mango'], ['Apple', 'Carrot'], Ellipsis]

# %%
import pandas as pd 

df = pd.read_csv("Purchase_Pattern_Analysis.csv")

# %%
Transaction = [1,19,28,33,36]
Products = ['Apple', 'Banana', 'Carrot', 'Dragon fruit', 'Eggs']
print(Transaction)
print(Products)
# Out:
# [1, 19, 28, 33, 36]
# ['Apple', 'Banana', 'Carrot', 'Dragon fruit', 'Eggs']

# %%
df = df.dropna(subset=['Product Category'])

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# Customer ID             int64
# Name                      str
# Surname                   str
# Gender                    str
# Birthdate                 str
# Transaction Amount    float64
# Date                      str
# Merchant Name             str
# Product Category          str
# Quantity              float64
# Price per Unit        float64
# Total Sales             int64
# dtype: object

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Purchase_Pattern_Analysis.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
products = ['Product A ', 'Product B', 'Product C', 'Product D', 'Product E',
            'Product F', 'Product G', 'Product H', 'Product I', 'Product J']
counts = np.random.randint(10, 100, size=10)
product_counts = pd.Series(counts, index=products)

# %%
product_counts.plot(kind='bar')
plt.title('Top 10 Most Frequent Products')
plt.xlabel('Products')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
transactions = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread'],
    ['Milk', 'Butter'],
    ['Bread', 'Butter']
]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
rules = pd.DataFrame({
    'support' : [0.1, 0.15, 0.2, 0.25, 0.3],
    'confidence' : [0.5, 0.6, 0.7, 0.8, 0.9]
})

# %%
plt.scatter(rules['support'], rules['confidence'])
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.title('Association Rules')
plt.show()

# %%
df = pd.read_csv("Purchase_Pattern_Analysis.csv")

# %%
transactions = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread'],
    ['Milk', 'Butter'],
    ['Bread']
]

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in e:\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in e:\anaconda3\lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in e:\anaconda3\lib\site-packages (from mlxtend) (2.4.4)
# Requirement already satisfied: pandas>=2.3.3 in e:\anaconda3\lib\site-packages (from mlxtend) (3.0.2)
# Requirement already satisfied: scikit-learn>=1.8.0 in e:\anaconda3\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in e:\anaconda3\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in e:\anaconda3\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in e:\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in e:\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# WARNING: Ignoring invalid distribution ~atplotlib (E:\Anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (E:\Anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (E:\Anaconda3\Lib\site-packages)

# %%
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

te = TransactionEncoder()
te_data = te.fit(transactions).transform(transactions)

df = pd.DataFrame(te_data, columns=te.columns_)
print(df)
# Out:
#    Bread  Butter   Milk
# 0   True    True   True
# 1   True    True  False
# 2   True   False   True
# 3  False    True   True
# 4   True   False  False

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)

print(frequent_itemsets)
# Out:
#    support                    itemsets
# 0      0.8          frozenset({Bread})
# 1      0.6         frozenset({Butter})
# 2      0.6           frozenset({Milk})
# 3      0.4  frozenset({Butter, Bread})
# 4      0.4    frozenset({Bread, Milk})
# 5      0.4   frozenset({Butter, Milk})

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

print(rules)
# Out:
#            antecedents          consequents  antecedent support  \
# 0  frozenset({Butter})   frozenset({Bread})                 0.6
# 1   frozenset({Bread})  frozenset({Butter})                 0.8
# 2   frozenset({Bread})    frozenset({Milk})                 0.8
# 3    frozenset({Milk})   frozenset({Bread})                 0.6
# 4  frozenset({Butter})    frozenset({Milk})                 0.6
# 5    frozenset({Milk})  frozenset({Butter})                 0.6
#
#    consequent support  support  confidence      lift  representativity  \
# 0                 0.8      0.4    0.666667  0.833333               1.0
# 1                 0.6      0.4    0.500000  0.833333               1.0
# 2                 0.6      0.4    0.500000  0.833333               1.0
# 3                 0.8      0.4    0.666667  0.833333               1.0
# 4                 0.6      0.4    0.666667  1.111111               1.0
# 5                 0.6      0.4    0.666667  1.111111               1.0
#
#    leverage  conviction  zhangs_metric  jaccard  certainty  kulczynski
# 0     -0.08         0.6      -0.333333      0.4  -0.666667    0.583333
# 1     -0.08         0.8      -0.500000      0.4  -0.250000    0.583333
# 2     -0.08         0.8      -0.500000      0.4  -0.250000    0.583333
# 3     -0.08         0.6      -0.333333      0.4  -0.666667    0.583333
# 4      0.04         1.2       0.250000      0.5   0.166667    0.666667
# 5      0.04         1.2       0.250000      0.5   0.166667    0.666667

# %%
strong_rules = rules[(rules['confidence'] > 0.6) & (rules['lift'] > 1)]
print(strong_rules)
# Out:
#            antecedents          consequents  antecedent support  \
# 4  frozenset({Butter})    frozenset({Milk})                 0.6
# 5    frozenset({Milk})  frozenset({Butter})                 0.6
#
#    consequent support  support  confidence      lift  representativity  \
# 4                 0.6      0.4    0.666667  1.111111               1.0
# 5                 0.6      0.4    0.666667  1.111111               1.0
#
#    leverage  conviction  zhangs_metric  jaccard  certainty  kulczynski
# 4      0.04         1.2           0.25      0.5   0.166667    0.666667
# 5      0.04         1.2           0.25      0.5   0.166667    0.666667

# %% [raw]
# import matplotlib.pyplot aas plt

# %%
frequent_itemsets.sort_values(by='support', ascending=False).head(10).plot(
    x='itemsets', y='support', kind='bar'
)
# Out:
# <Axes: xlabel='itemsets'>

# %%
import seaborn as sns
import pandas as pd

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.scatter(rules['support'], rules['confidence'], s=rules['lift']*100)

plt.xlabel('Support')
plt.ylabel('Confidence')
plt.title('Support vs Confidence ( Lift as size)')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.DiGraph()

for _, row in rules.iterrows():
    G.add_edge(str(row['antecedents']),
               str(row['consequents']),
               weight=row['lift'])

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=2000)

plt.title('Product Relationship Network')
plt.show()

# %%
plt.scatter(rules['support'], rules['confidence'],
            s=rules['lift']*100)
plt.xlabel("Support")
plt.ylabel("Confidence")
plt.title("Product Relationship Strength")
plt.show()

# %%
transactions = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread'],
    ['Milk', 'Butter'],
    ['Bread', 'Butter']
]

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in e:\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in e:\anaconda3\lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in e:\anaconda3\lib\site-packages (from mlxtend) (2.4.4)
# Requirement already satisfied: pandas>=2.3.3 in e:\anaconda3\lib\site-packages (from mlxtend) (3.0.2)
# Requirement already satisfied: scikit-learn>=1.8.0 in e:\anaconda3\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in e:\anaconda3\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in e:\anaconda3\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in e:\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in e:\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (E:\Anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (E:\Anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (E:\Anaconda3\Lib\site-packages)

# %%
import pandas as  pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_data = te.fit(transactions).transform(transactions)

df = pd.DataFrame(te_data, columns=te.columns_)
print(df)
# Out:
#    Bread  Butter   Milk
# 0   True    True   True
# 1   True    True  False
# 2   True   False   True
# 3  False    True   True
# 4   True    True  False

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)
print(frequent_itemsets)
# Out:
#    support                    itemsets
# 0      0.8          frozenset({Bread})
# 1      0.8         frozenset({Butter})
# 2      0.6           frozenset({Milk})
# 3      0.6  frozenset({Butter, Bread})
# 4      0.4    frozenset({Bread, Milk})
# 5      0.4   frozenset({Butter, Milk})

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
print(rules)
# Out:
#            antecedents          consequents  antecedent support  \
# 0  frozenset({Butter})   frozenset({Bread})                 0.8
# 1   frozenset({Bread})  frozenset({Butter})                 0.8
# 2    frozenset({Milk})   frozenset({Bread})                 0.6
# 3    frozenset({Milk})  frozenset({Butter})                 0.6
#
#    consequent support  support  confidence      lift  representativity  \
# 0                 0.8      0.6    0.750000  0.937500               1.0
# 1                 0.8      0.6    0.750000  0.937500               1.0
# 2                 0.8      0.4    0.666667  0.833333               1.0
# 3                 0.8      0.4    0.666667  0.833333               1.0
#
#    leverage  conviction  zhangs_metric  jaccard  certainty  kulczynski
# 0     -0.04         0.8      -0.250000      0.6  -0.250000    0.750000
# 1     -0.04         0.8      -0.250000      0.6  -0.250000    0.750000
# 2     -0.08         0.6      -0.333333      0.4  -0.666667    0.583333
# 3     -0.08         0.6      -0.333333      0.4  -0.666667    0.583333
